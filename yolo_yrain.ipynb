# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("rajsinghbani/lisa-yolov7-formatted")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 1.10G/1.10G [00:53<00:00, 22.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/rajsinghbani/lisa-yolov7-formatted/versions/3

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolo11m.pt")

results = model.train(data=f"{path}/LISAyoloFormat/yolov7data.yaml", epochs=300)
# Out:
# ...
# 100%|██████████| 38.8M/38.8M [00:00<00:00, 595MB/s]
# Ultralytics 8.3.95 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# ...

# %%
best_model = YOLO("/content/runs/detect/train/weights/best.pt")

best_model.predict("/content/istockphoto-1452422471-640_adpp_is.mp4", show=True, save=True, line_width=2)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/620) /content/istockphoto-1452422471-640_adpp_is.mp4: 384x640 2 light_greens, 15.0ms
# video 1/1 (frame 2/620) /content/istockphoto-1452422471-640_adpp_is.mp4: 384x640 3 light_greens, 13.8ms
# video 1/1 (frame 3/620) /content/istockphoto-1452422471-640_adpp_is.mp4: 384x640 2 light_greens, 13.4ms
# ...
